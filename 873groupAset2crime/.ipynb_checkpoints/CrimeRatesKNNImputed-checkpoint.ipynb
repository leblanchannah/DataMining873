# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# %%
#KNN imputed missing values - credit Justin Gerolami
df_train_knn = pd.read_csv('Imputed_Train.csv')

# %% [markdown]
# ### Dataset Info

# %%
print("Shape: ",df_train_knn.shape)
# number of null values in each column, 0 
# print(df_train_knn.isnull().sum(axis = 0))
df_train_knn.describe()
# Out:
# Shape:  (504, 120)
#              Year  Robbery_rate  Property_crime_rate  Burglary_rate  \
# count  504.000000    504.000000           504.000000     504.000000
# mean     1.515873    174.216865          3794.012174     859.891468
# std      0.500245    145.068378          1520.936903     491.452388
# min      1.000000      0.000000           210.700000      51.400000
# 25%      1.000000     63.900000          2623.800000     489.000000
# 50%      2.000000    138.050000          3509.250000     756.150000
# 75%      2.000000    228.300000          4813.275000    1112.550000
# max      2.000000    739.500000          8730.100000    2773.800000
#
#        Larceny_theft_rate  Motor_vehicle_theft_rate    Population  \
# count          504.000000                504.000000  5.040000e+02
# mean          2545.005574                390.622619  1.964265e+05
# std           1016.150549                292.667286  3.523808e+05
# min            149.000000                  6.200000  1.341900e+04
# 25%           1761.225000                165.550000  7.941050e+04
# 50%           2362.150000                301.750000  1.012360e+05
# 75%           3211.225000                536.600000  1.816388e+05
# max           5958.500000               1777.000000  3.855122e+06
#
#        Total law_enforcement_employees  \
# count                       504.000000
# mean                        446.662698
# std                        1256.162456
# min                           1.000000
# 25%                         122.750000
# 50%                         201.000000
# 75%                         356.250000
# max                       13960.000000
#
#        Law_enforcement_Total officers emloyee  Total civilians employee  \
# count                              504.000000                504.000000
# mean                               349.773810                 96.878968
# std                               1066.217627                226.800135
# min                                  1.000000                  0.000000
# 25%                                 86.000000                 27.000000
# 50%                                148.500000                 49.500000
# 75%                                271.250000                 95.500000
# max                              13088.000000               3215.000000
#
#                              ...                         \
# count                        ...
# mean                         ...
# std                          ...
# min                          ...
# 25%                          ...
# 50%                          ...
# 75%                          ...
# max                          ...
#
#        Percent of houdsehold with children under 18; AGE OF OWN CHILDREN - Under 6 years and 6 to 17 years  \
# count                                         504.000000
# mean                                           20.927778
# std                                             5.193399
# min                                             6.100000
# 25%                                            17.675000
# 50%                                            20.900000
# 75%                                            24.400000
# max                                            40.300000
#
#        Percent of houdsehold with children under 18; AGE OF OWN CHILDREN - 6 to 17 years only  \
# count                                         504.000000
# mean                                           54.890873
# std                                             6.559045
# min                                            32.500000
# 25%                                            50.600000
# 50%                                            54.700000
# 75%                                            59.000000
# max                                            74.300000
#
#        Civilian employed population 16 years and over - Government workers  \
# count                                         504.000000
# mean                                           13.840482
# std                                             5.164315
# min                                             4.800000
# 25%                                            10.400000
# 50%                                            12.700000
# 75%                                            16.500000
# max                                            40.200000
#
#        Civilian employed population 16 years and over - Private wage and salary workers  \
# count                                         504.000000
# mean                                           80.191571
# std                                             5.679446
# min                                            51.000000
# 25%                                            77.200000
# 50%                                            81.100000
# 75%                                            84.025000
# max                                            93.100000
#
#        Civilian employed population 16 years and over - Self-employed workers in own not incorporated business  \
# count                                         504.000000
# mean                                            5.842824
# std                                             2.288553
# min                                             1.900000
# 25%                                             4.300000
# 50%                                             5.500000
# 75%                                             6.900000
# max                                            15.200000
#
#        Civilian employed population 16 years and over - Unpaid family workers  \
# count                                         504.000000
# mean                                            0.126098
# std                                             0.156353
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.100000
# 75%                                             0.200000
# max                                             1.300000
#
#        percentage_ Total: - 1-person household:  \
# count                                504.000000
# mean                                  28.858723
# std                                    7.645760
# min                                   10.404093
# 25%                                   23.295118
# 50%                                   29.420723
# 75%                                   34.348578
# max                                   52.762473
#
#        percentage_ Total: - 2-person household:  \
# count                                504.000000
# mean                                  30.869111
# std                                    4.480280
# min                                   13.980969
# 25%                                   27.948767
# 50%                                   31.217555
# 75%                                   33.636465
# max                                   45.230130
#
#        percentage_ Total: - 3-person household:  \
# count                                504.000000
# mean                                  15.987119
# std                                    2.753192
# min                                    8.260291
# 25%                                   14.095336
# 50%                                   15.835624
# 75%                                   17.740791
# max                                   24.790949
#
#        percentage_ Total: - 4-or-more-person household:
# count                                        504.000000
# mean                                          24.285046
# std                                            8.536256
# min                                            8.067218
# 25%                                           18.248628
# 50%                                           22.398415
# 75%                                           28.786602
# max                                           56.302475
#
# [8 rows x 119 columns]

# %% [markdown]
# ### Splitting Year = 1 and Year = 2 into two datasets

# %%
df_train_one = df_train_knn[df_train_knn["Year"]==1]
print("Shape: ",df_train_one.shape)
df_train_two = df_train_knn[df_train_knn["Year"]==2]
print("Shape: ",df_train_two.shape)
# Out:
# Shape:  (244, 120)
# Shape:  (260, 120)

# %% [markdown]
# #### Year 1 Crime Rates and Year 2 Crime Rates

# %%
def boxplot(x_data, y_data, base_color="#539caf", median_color="#297083", x_label="", y_label="", title=""):
    _, ax = plt.subplots()

    # Draw boxplots, specifying desired style
    ax.boxplot(y_data
               # patch_artist must be True to control box fill
               , patch_artist = True
               # Properties of median line
               , medianprops = {'color': median_color}
               # Properties of box
               , boxprops = {'color': base_color, 'facecolor': base_color}
               # Properties of whiskers
               , whiskerprops = {'color': base_color}
               # Properties of whisker caps
               , capprops = {'color': base_color})
    

    # By default, the tick label starts at 1 and increments by 1 for
    # each box drawn. This sets the labels to the ones we want
    ax.set_xticklabels(x_data)
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
    ax.set_title(title)
def lineplot(x_data, y_data, x_label="", y_label="", title=""):
    # Create the plot object
    _, ax = plt.subplots()

    # Plot the best fit line, set the linewidth (lw), color and
    # transparency (alpha) of the line
    ax.plot(x_data[0], y_data[0], lw = 2, color = '#539caf', alpha = 1)
    ax.plot(x_data[1], y_data[1], lw = 2, color = 'r', alpha = 1)

    # Label the axes and provide a title
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

# %%
lineplot([range(df_train_one.shape[0]),range(df_train_two.shape[0])],[df_train_one["Property_crime_rate"],df_train_two["Property_crime_rate"]],"City","Property Crime Rate","Year 1")
# xdata = ['Robbery_rate', 'Property_crime_rate', 'Burglary_rate','Larceny_theft_rate', 'Motor_vehicle_theft_rate']
# boxplot(xdata,df_train_one[['Robbery_rate', 'Property_crime_rate', 'Burglary_rate','Larceny_theft_rate', 'Motor_vehicle_theft_rate']])

# %% [markdown]
# ### qcut pandas

# %%
bins = 3
y = pd.DataFrame()
y["Property_crime_rate"] = pd.cut(df_train_knn["Property_crime_rate"], bins, labels=range(bins), retbins=False, precision=3, duplicates='raise')
y['Burglary_rate'] = pd.cut(df_train_knn['Burglary_rate'], bins, labels=range(bins), retbins=False, precision=3, duplicates='raise')
y['Larceny_theft_rate'] = pd.cut(df_train_knn['Larceny_theft_rate'], bins, labels=range(bins), retbins=False, precision=3, duplicates='raise')
y['Motor_vehicle_theft_rate'] = pd.cut(df_train_knn['Motor_vehicle_theft_rate'], bins, labels=range(bins), retbins=False, precision=3, duplicates='raise')
y['Robbery_rate'] = pd.cut(df_train_knn['Robbery_rate'], bins, labels=range(bins), retbins=False, precision=3, duplicates='raise')

# %%
X = df_train_knn.drop(columns=['Robbery_rate', 'Property_crime_rate', 'Burglary_rate','Larceny_theft_rate', 'Motor_vehicle_theft_rate','City'])

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
y = y.apply(lambda x : pd.Series(x, dtype='int32'),axis=0)

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 5 columns):
# Property_crime_rate         504 non-null int32
# Burglary_rate               504 non-null int32
# Larceny_theft_rate          504 non-null int32
# Motor_vehicle_theft_rate    504 non-null int32
# Robbery_rate                504 non-null int32
# dtypes: int32(5)
# memory usage: 9.9 KB

# %% [markdown]
# #### SVC Model

# %%
model = SVC()

# %%
y_pred = cross_val_predict(model, X, y['Robbery_rate'], cv=5)
print(metrics.classification_report(y["Robbery_rate"], y_pred))

y_pred = cross_val_predict(model, X, y['Property_crime_rate'], cv=5)
print(metrics.classification_report(y[ 'Property_crime_rate'], y_pred))

y_pred = cross_val_predict(model, X, y['Burglary_rate'], cv=5)
print(metrics.classification_report(y['Burglary_rate'], y_pred))

y_pred = cross_val_predict(model, X, y['Larceny_theft_rate'], cv=5)
print(metrics.classification_report(y['Larceny_theft_rate'], y_pred))

y_pred = cross_val_predict(model, X, y['Motor_vehicle_theft_rate'], cv=5)
print(metrics.classification_report(y['Motor_vehicle_theft_rate'], y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.84      0.97      0.90       392
#           1       0.49      0.30      0.37        88
#           2       0.00      0.00      0.00        24
#
# avg / total       0.74      0.80      0.76       504
#
#              precision    recall  f1-score   support
#
#           0       0.71      0.61      0.66       188
#           1       0.64      0.82      0.72       265
#           2       1.00      0.02      0.04        51
#
# avg / total       0.70      0.66      0.63       504
#
#              precision    recall  f1-score   support
#
#           0       0.79      0.87      0.83       335
#           1       0.52      0.49      0.50       142
#           2       0.60      0.11      0.19        27
#
# avg / total       0.71      0.72      0.70       504
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       0.72      0.58      0.64       194
#           1       0.64      0.83      0.72       266
#           2       0.00      0.00      0.00        44
#
# avg / total       0.61      0.66      0.63       504
#
#              precision    recall  f1-score   support
#
#           0       0.81      0.99      0.89       402
#           1       0.45      0.05      0.10        93
#           2       0.00      0.00      0.00         9
#
# avg / total       0.73      0.80      0.73       504
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
